# %%
import os

zip_file_paths = ['train.zip', 'validation.zip']

# Ensure 'unzipped' directory exists
if not os.path.exists('unzipped'):
    os.mkdir('unzipped')

for path in zip_file_paths:
    name = str(path)
    destination_folder = f'unzipped/{name.split(".")[0]}'
    
    # Ensure destination folder exists
    if not os.path.exists(destination_folder):
        os.mkdir(destination_folder)
    
    os.system(f'unzip {path} -d {destination_folder}')
# Out:
# Archive:  train.zip
#    creating: unzipped/train/train/data/
#   inflating: unzipped/train/train/data/0005a922e055c723.jpg
#   inflating: unzipped/train/train/data/000610ca2148a5ec.jpg
#   inflating: unzipped/train/train/data/00075e339f3d4f37.jpg
#   inflating: unzipped/train/train/data/00097c09aca0cabf.jpg
#   inflating: unzipped/train/train/data/002c60d5fbc94244.jpg
#   inflating: unzipped/train/train/data/002e531370b773ea.jpg
#   inflating: unzipped/train/train/data/0034c7d615675754.jpg
#   inflating: unzipped/train/train/data/003bfa647c199309.jpg
#   inflating: unzipped/train/train/data/004bd64410736c69.jpg
#   inflating: unzipped/train/train/data/004d150f127cfba6.jpg
#   inflating: unzipped/train/train/data/005f6296062603a9.jpg
#   inflating: unzipped/train/train/data/007653c739edf912.jpg
#   inflating: unzipped/train/train/data/00782bbf3bcee6cd.jpg
#   inflating: unzipped/train/train/data/007f9091b4afffe4.jpg
#   inflating: unzipped/train/train/data/00839c7e26f5c5e0.jpg
# ...

# %%
import pandas as pd

df_validation = pd.read_csv('unzipped/validation/validation/labels/detections.csv')
df_validation.head()
# Out:
#             ImageID  Source LabelName  Confidence      XMin      XMax  \
# 0  0001eeaf4aed83f9  xclick  /m/0cmf2           1  0.022673  0.964201
# 1  000595fe6fee6369  xclick  /m/02wbm           1  0.000000  1.000000
# 2  000595fe6fee6369  xclick  /m/02xwb           1  0.141384  0.179676
# 3  000595fe6fee6369  xclick  /m/02xwb           1  0.213549  0.253314
# 4  000595fe6fee6369  xclick  /m/02xwb           1  0.232695  0.288660
#
#        YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 0  0.071038  0.800546           0            0          0            0
# 1  0.000000  1.000000           0            0          1            0
# 2  0.676275  0.731707           0            0          0            0
# 3  0.299335  0.354767           1            0          0            0
# 4  0.490022  0.545455           1            0          0            0
#
#    IsInside
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
import pandas as pd

df_train = pd.read_csv('unzipped/train/train/labels/detections.csv')
df_train.head()
# Out:
#             ImageID  Source  LabelName  Confidence      XMin      XMax  \
# 0  000002b66c9c498e  xclick  /m/01g317           1  0.012500  0.195312
# 1  000002b66c9c498e  xclick  /m/01g317           1  0.025000  0.276563
# 2  000002b66c9c498e  xclick  /m/01g317           1  0.151562  0.310937
# 3  000002b66c9c498e  xclick  /m/01g317           1  0.256250  0.429688
# 4  000002b66c9c498e  xclick  /m/01g317           1  0.257812  0.346875
#
#        YMin      YMax  IsOccluded  IsTruncated  ...  IsDepiction  IsInside  \
# 0  0.148438  0.587500           0            1  ...            0         0
# 1  0.714063  0.948438           0            1  ...            0         0
# 2  0.198437  0.590625           1            0  ...            0         0
# 3  0.651563  0.925000           1            0  ...            0         0
# 4  0.235938  0.385938           1            0  ...            0         0
#
#    XClick1X  XClick2X  XClick3X  XClick4X  XClick1Y  XClick2Y  XClick3Y  \
# ...

# %%
len(df_train)
# Out:
# 14610229

# %%
len(df_validation)
# Out:
# 303980

# %%
data_path_validation = "unzipped/validation/validation/data/*.jpg"
data_path_train = "unzipped/train/train/data/*.jpg"

# %%
import glob  #recursively loop directories
counter = 0

img_paths = data_path_train
folder = glob.glob(img_paths)

for i in folder:
    counter+=1
print(counter)
# Out:
# 517

# %%
import glob  #recursively loop directories
counter = 0

img_paths = data_path_validation
folder = glob.glob(img_paths)

for i in folder:
    counter+=1
print(counter)
# Out:
# 9

# %%
#Get image ids

import glob
train_list_ids = []
validation_list_ids =[]

#validation: Start position: 32,End position: 47

def get_ids(split, print_this, to_append_list):
    start = 0
    end = 0
    if split == data_path_train:
        start, end = 26, 42
    elif split == data_path_validation:
        start, end = 36,52
    else:
        raise Exception("Invalid Parameter")
    folder = split
    img_paths = glob.glob(folder)
    img_ids = to_append_list
    
    for i in img_paths:
        id= i[start:end]
        img_ids.append(id)
    print(len(img_ids))
    print(print_this)

# %%
get_ids(data_path_train, "I finished the task", train_list_ids)
# Out:
# 517
# I finished the task

# %%
train_list_ids[0]
# Out:
# '35c117011545b09b'

# %%
get_ids(data_path_validation, "I finished the task", validation_list_ids)
# Out:
# 9
# I finished the task

# %%
validation_list_ids[0]
# Out:
# '4e24222b68123ef3'
